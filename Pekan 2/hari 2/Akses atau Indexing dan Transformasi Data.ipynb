# %% [markdown]
# Ada banyak cara-cara kita indexing suatu dataframe. diantranya adalah dengan menggunakan :
#
# - dataframe[] : cara seperti ini dikenal sebagai index operator.
# - dataframe.loc[]: operator yang menggunakan label untuk mengakses data, jika misalkan kamu melakukan dataframe.loc[‘jumlah’], berarti kamu hendak mengakses data yang mempunyai index jumlah
# - dataframe.iloc[: operator yang menggunakan posisi index untuk mengakses data. jikalau kamu melakukan dataframe.iloc[2] berarti kamu hendak mengakses dataframe dengan index posisi 2

# %% [markdown]
# # Filtering DataFrame with Boolean

# %%
# !dir
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is C008-E6DD
#
#  Directory of D:\Study\SanberCode\Python - Data Science\Pekan 2\hari 2
#
# 07/10/2020  14:41    <DIR>          .
# 07/10/2020  14:41    <DIR>          ..
# 07/10/2020  13:57    <DIR>          .ipynb_checkpoints
# 07/10/2020  10:21             1.324 Akses atau Indexing dan Transformasi Data.ipynb
# 06/10/2020  21:24            53.734 Live Session 7 Update.ipynb
# 06/10/2020  21:19            23.513 Live Session 7.ipynb
# 07/10/2020  10:22            60.301 titanic.csv
# 07/10/2020  14:41            22.825 Tugas Hari 2 Pekan 2.ipynb
#                5 File(s)        161.697 bytes
#                3 Dir(s)  265.045.749.760 bytes free

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# indexing dataframe
## cara 1 --> dataframe[]: cara index operator
df['Name'] # return berbentuk series, jika mau tetap berbentuk dataframe bisa gunakan cara pada cell selanjutnya
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[['Name']]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
# indexing dataframe
## cara 2 --> dataframe.loc[]: operator yang menggunakan label untuk akses data
### misal, dataframe.loc['jumlah'] --> berarti hendak akses data dengan index jumlah
df.loc[[2]]
# Out:
#    PassengerId  Survived  Pclass                    Name     Sex   Age  SibSp  \
# 2            3         1       3  Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 2      0  STON/O2. 3101282  7.925   NaN        S

# %%
df.loc[[2, 3, 5]]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 5            330877   8.4583   NaN        Q

# %%
df.loc[2:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q

# %%
# indexing dataframe
## cara 3 --> dataframe.iloc[]: operator yang menggunakan posisi index untuk akses data
### misal, dataframe.iloc[2] --> berarti hendak akses dataframe dengan index posisi 2
df.iloc[[2]]
# Out:
#    PassengerId  Survived  Pclass                    Name     Sex   Age  SibSp  \
# 2            3         1       3  Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 2      0  STON/O2. 3101282  7.925   NaN        S

# %%
df.iloc[1:3, 0:3]
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1
# 2            3         1       3

# %%
df[df.PassengerId == 10]
# Out:
#    PassengerId  Survived  Pclass                                 Name     Sex  \
# 9           10         1       2  Nasser, Mrs. Nicholas (Adele Achem)  female
#
#     Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 9  14.0      1      0  237736  30.0708   NaN        C

# %% [markdown]
# # Filtering DataFrame dimulai dari pertanyaan

# %% [markdown]
# **Soal**
# 1. Tunjukan kepada saya semua data orang-orang yang selamat!!
# 2. Tunjukan kepada saya semua data laki-laki yang selamat.
# 3. Tunjukan kepada saya semua data tentang perempuan yang tidak selamat di umur lebih dari 40 tahun atau kurang dari 20 tahun.

# %%
# 1
df[df.Survived == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 875      0              2667   7.2250   NaN        C
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
#
# [342 rows x 12 columns]

# %%
# 2
df[(df['Sex'] == 'male') & (df.Survived == 1)]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 17    NaN      0      0  244373  13.0000   NaN        S
# 21   34.0      0      0  248698  13.0000   D56        S
# 23   28.0      0      0  113788  35.5000    A6        S
# 36    NaN      0      0    2677   7.2292   NaN        C
# 55    NaN      0      0   19947  35.5000   C52        S
# ..    ...    ...    ...     ...      ...   ...      ...
# 838  32.0      0      0    1601  56.4958   NaN        S
# 839   NaN      0      0   11774  29.7000   C47        C
# 857  51.0      0      0  113055  26.5500   E17        S
# 869   4.0      1      1  347742  11.1333   NaN        S
# 889  26.0      0      0  111369  30.0000  C148        C
#
# [109 rows x 12 columns]

# %%
# 3
# Tunjukan kepada saya semua data tentang perempuan yang tidak selamat
# di umur lebih dari 40 tahun atau kurang dari 20 tahun.
df[((df.Sex == 'female') & (df['Survived'] == 0)) & ((df.Age > 40) | (df.Age < 20))]
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 24            25         0       3
# 38            39         0       3
# 49            50         0       3
# 71            72         0       3
# 111          112         0       3
# 114          115         0       3
# 119          120         0       3
# 132          133         0       3
# 147          148         0       3
# 167          168         0       3
# 177          178         0       1
# 205          206         0       3
# 254          255         0       3
# 276          277         0       3
# 297          298         0       1
# 362          363         0       3
# 374          375         0       3
# 419          420         0       3
# 541          542         0       3
# 542          543         0       3
# 634          635         0       3
# 638          639         0       3
# 642          643         0       3
# 654          655         0       3
# 678          679         0       3
# 702          703         0       3
# 736          737         0       3
# 772          773         0       2
# 807          808         0       3
# 813          814         0       3
# 852          853         0       3
# 854          855         0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 14              Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 24                     Palsson, Miss. Torborg Danira  female   8.0      3
# 38                Vander Planke, Miss. Augusta Maria  female  18.0      2
# 49     Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 71                        Goodwin, Miss. Lillian Amy  female  16.0      5
# 111                             Zabour, Miss. Hileni  female  14.5      1
# 114                            Attalah, Miss. Malake  female  17.0      0
# 119                Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 132   Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.0      1
# 147                 Ford, Miss. Robina Maggie "Ruby"  female   9.0      2
# 167  Skoog, Mrs. William (Anna Bernhardina Karlsson)  female  45.0      1
# 177                       Isham, Miss. Ann Elizabeth  female  50.0      0
# 205                       Strom, Miss. Telma Matilda  female   2.0      0
# 254         Rosblom, Mrs. Viktor (Helena Wilhelmina)  female  41.0      0
# 276                Lindblom, Miss. Augusta Charlotta  female  45.0      0
# 297                     Allison, Miss. Helen Loraine  female   2.0      1
# 362                  Barbara, Mrs. (Catherine David)  female  45.0      0
# 374                       Palsson, Miss. Stina Viola  female   3.0      3
# 419                        Van Impe, Miss. Catharina  female  10.0      0
# 541             Andersson, Miss. Ingeborg Constanzia  female   9.0      4
# 542                Andersson, Miss. Sigrid Elisabeth  female  11.0      4
# 634                               Skoog, Miss. Mabel  female   9.0      3
# 638           Panula, Mrs. Juha (Maria Emilia Ojala)  female  41.0      0
# 642                    Skoog, Miss. Margit Elizabeth  female   2.0      3
# 654                     Hegarty, Miss. Hanora "Nora"  female  18.0      0
# 678          Goodwin, Mrs. Frederick (Augusta Tyler)  female  43.0      1
# 702                            Barbara, Miss. Saiide  female  18.0      0
# 736          Ford, Mrs. Edward (Margaret Ann Watson)  female  48.0      1
# 772                                Mack, Mrs. (Mary)  female  57.0      0
# 807                  Pettersson, Miss. Ellen Natalia  female  18.0      0
# 813               Andersson, Miss. Ebba Iris Alfrida  female   6.0      4
# 852                          Boulos, Miss. Nourelain  female   9.0      1
# 854    Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female  44.0      1
#
#      Parch       Ticket      Fare    Cabin Embarked
# 14       0       350406    7.8542      NaN        S
# 24       1       349909   21.0750      NaN        S
# 38       0       345764   18.0000      NaN        S
# 49       0       349237   17.8000      NaN        S
# 71       2      CA 2144   46.9000      NaN        S
# 111      0         2665   14.4542      NaN        C
# 114      0         2627   14.4583      NaN        C
# 119      2       347082   31.2750      NaN        S
# 132      0    A/5. 3337   14.5000      NaN        S
# 147      2   W./C. 6608   34.3750      NaN        S
# 167      4       347088   27.9000      NaN        S
# 177      0     PC 17595   28.7125      C49        C
# 205      1       347054   10.4625       G6        S
# 254      2       370129   20.2125      NaN        S
# 276      0       347073    7.7500      NaN        S
# 297      2       113781  151.5500  C22 C26        S
# 362      1         2691   14.4542      NaN        C
# 374      1       349909   21.0750      NaN        S
# 419      2       345773   24.1500      NaN        S
# 541      2       347082   31.2750      NaN        S
# 542      2       347082   31.2750      NaN        S
# 634      2       347088   27.9000      NaN        S
# 638      5      3101295   39.6875      NaN        S
# 642      2       347088   27.9000      NaN        S
# 654      0       365226    6.7500      NaN        Q
# 678      6      CA 2144   46.9000      NaN        S
# 702      1         2691   14.4542      NaN        C
# 736      3   W./C. 6608   34.3750      NaN        S
# 772      0  S.O./P.P. 3   10.5000      E77        S
# 807      0       347087    7.7750      NaN        S
# 813      2       347082   31.2750      NaN        S
# 852      1         2678   15.2458      NaN        C
# 854      0       244252   26.0000      NaN        S

# %% [markdown]
# # Data Transformation
#
# Data transformasi adalah mengubah format data kepada suatu format yang kita inginkan. didalam matematika dikenal dengan istilah mapping. dalam melakukan transformasi kita memerlukan terlebih dahulu suatu fungsi yang dapat memetkan bentuk data awal kita menjadi bentuk data akhir yang kita inginkan.

# %%
def minus_minimum(x):
    return x - x.min()

# %%
df[['Age']].head()
# Out:
#     Age
# 0  22.0
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0

# %%
df['TransformAge'] = df[['Age']].apply(minus_minimum)
df[['Age', 'TransformAge']]
# Out:
#       Age  TransformAge
# 0    22.0         21.58
# 1    38.0         37.58
# 2    26.0         25.58
# 3    35.0         34.58
# 4    35.0         34.58
# ..    ...           ...
# 886  27.0         26.58
# 887  19.0         18.58
# 888   NaN           NaN
# 889  26.0         25.58
# 890  32.0         31.58
#
# [891 rows x 2 columns]

# %%
# dictionary-style (lebih prefer ini untuk digunakan)
df['nilai']

# attribute-style (kurang dianjurkan, karena memungkinkan nantinya terjadi tabrakan method, contohnya attr pop dan columnya pop juga)
df.nilai
